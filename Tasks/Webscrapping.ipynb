# %%
import re
import requests
from bs4 import BeautifulSoup
import json

# URL of the HTML content
url = 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/SR_SANKALP_QP_GT-513-01-2023ONLI.html'

# Fetch the HTML content from the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    html_content = response.text
    #print(html_content)

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize a list to hold all questions
    questions_list = []

    specific_pattern = re.compile(r'rvps\d+')
    # Find all elements containing questions
    #question_elements = soup.find_all('table', class_='')  # Replace with your actual class name for questions
    question_elements = soup.find_all('div', class_=specific_pattern)  # Replace with your actual class name for questions
    #print(question_elements)
    for question_elem in question_elements:
        specific_pattern = re.compile(r'rvps\d+')
        question_table = question_elem.find('table')
        question_trs=question_table.find_all('tr')
        for question_tr in question_trs:
            question_tr_tds=question_tr.find_all('td')
            
            print(question_tr_tds)
        
        #print(question_tr_tds)
        #question_p=question_tr.find()
        
    """# Loop through each question element
    for question_elem in question_elements:
        # Extract the question text
        question_text_elem = question_elem.find('p')  # Replace with the correct tag containing question text
        if question_text_elem:
            question_text = question_text_elem.text.strip()
        else:
            print("Question text not found")
            continue

        # Extract the options
        options_elements = question_elem.find_all('tr')  # Replace with your actual class name for options

        # Initialize dictionary to store options
        options_dict = {}

        # Loop through each option element
        for option_elem in options_elements:
            # Extract option label (A, B, C, D)
            option_label_elem = option_elem.find('td', class_='QuesOtpnLbl')  # Replace with correct tag and class for option label
            option_text_elem = option_elem.find('td', class_='QuesOtpnTxt')  # Replace with correct tag and class for option text

            if option_label_elem and option_text_elem:
                option_label = option_label_elem.text.strip()
                option_text = option_text_elem.text.strip()
                # Add option to options dictionary
                options_dict[option_label] = option_text
            else:
                print("Incomplete option found")

        # Create dictionary for the question with options
        question_dict = {
            'question': question_text,
            'options': options_dict
        }

        # Append question dictionary to questions list
        questions_list.append(question_dict)

    # Convert questions list to JSON format
    questions_json = json.dumps(questions_list, indent=4, ensure_ascii=False)

    # Print JSON output
    print(questions_json)"""

    # Optionally, save JSON output to a file
    #with open('questions.json', 'w', encoding='utf-8') as json_file:
        #json_file.write(questions_json)

else:
    print(f"Failed to retrieve the URL. Status code: {response.status_code}")
# Out:
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 55px;">
# <p class="rvps6"><span class="rvts48">1.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 421px; height: 55px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%20298.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 29px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 29px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 208px; height: 29px;">
# <p class="rvps5"><span class="rvts51"><br/></span></p>
# <p class="rvps10"><img alt="" src="lib/NewItem%20297.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 95px; height: 29px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 71px; height: 29px;">
# <p class="rvps5"><span class="rvts54"><br/></span></p>
# <p class="rvps12"><img alt="" src="lib/NewItem%20296.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 30px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 30px;">
# <p class="rvps13"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 208px; height: 30px;">
# <p class="rvps7"><span class="rvts52"><br/></span></p>
# <p class="rvps14"><img alt="" src="lib/NewItem%20295.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 95px; height: 30px;">
# <p class="rvps15"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 71px; height: 30px;">
# <p class="rvps2"><span class="rvts55"><br/></span></p>
# <p class="rvps16"><img alt="" src="lib/NewItem%20294.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 85px;">
# <p class="rvps6"><span class="rvts57">2.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 638px; height: 85px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps19"><img alt="" src="lib/NewItem%20293.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 52px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 52px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 194px; height: 52px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20292.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 108px; height: 52px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 289px; height: 52px;">
# <p class="rvps7"><span class="rvts58"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20291.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 48px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 48px;">
# <p class="rvps22"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 194px; height: 48px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20290.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 108px; height: 48px;">
# <p class="rvps24"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 289px; height: 48px;">
# <p class="rvps7"><span class="rvts59"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20289.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 89px;">
# <p class="rvps6"><span class="rvts48">3.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 644px; height: 89px;">
# <p class="rvps7"><span class="rvts39"><br/></span></p>
# <p class="rvps26"><img alt="" src="lib/NewItem%20288.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 33px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 33px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 33px;">
# <p class="rvps5"><span class="rvts61"><br/></span></p>
# <p class="rvps27"><img alt="" src="lib/NewItem%20287.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 33px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 295px; height: 33px;">
# <p class="rvps2"><span class="rvts51"><br/></span></p>
# <p class="rvps28"><img alt="" src="lib/NewItem%20286.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 28px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 28px;">
# <p class="rvps29"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 28px;">
# <p class="rvps5"><span class="rvts51"><br/></span></p>
# <p class="rvps30"><img alt="" src="lib/NewItem%20285.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 28px;">
# <p class="rvps31"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 295px; height: 28px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps32"><img alt="" src="lib/NewItem%20284.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 111px;">
# <p class="rvps6"><span class="rvts57">4.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 641px; height: 111px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps33"><img alt="" src="lib/NewItem%20283.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 50px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 50px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 159px; height: 50px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%20282.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 143px; height: 50px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 292px; height: 50px;">
# <p class="rvps7"><span class="rvts52"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20281.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 42px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 42px;">
# <p class="rvps35"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 159px; height: 42px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps36"><img alt="" src="lib/NewItem%20280.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 143px; height: 42px;">
# <p class="rvps37"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 292px; height: 42px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps38"><img alt="" src="lib/NewItem%20279.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 65px;">
# <p class="rvps6"><span class="rvts57">5.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 634px; height: 65px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps36"><img alt="" src="lib/NewItem%20278.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 32px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 32px;">
# <p class="rvps40"><span class="rvts64">1</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 284px; height: 32px;">
# <p class="rvps41"><span class="rvts64">4</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 45px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 45px;">
# <p class="rvps42"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 45px;">
# <p class="rvps2"><span class="rvts63"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20277.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 45px;">
# <p class="rvps43"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 284px; height: 45px;">
# <p class="rvps41"><span class="rvts64">0</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 51px;">
# <p class="rvps6"><span class="rvts57">6.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 600px; height: 51px;">
# <p class="rvps7"><span class="rvts67"><br/></span></p>
# <p class="rvps46"><img alt="" src="lib/NewItem%20276.jpg" style="width : 571px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 32px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 161px; height: 32px;">
# <p class="rvps40"><span class="rvts50">99</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 141px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 250px; height: 32px;">
# <p class="rvps41"><span class="rvts50">100</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 27px;">
# <p class="rvps47"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 161px; height: 27px;">
# <p class="rvps48"><span class="rvts50">101</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 141px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 250px; height: 27px;">
# <p class="rvps50"><span class="rvts50">102</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 39px;">
# <p class="rvps6"><span class="rvts57">7.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 318px; height: 39px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20275.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 31px; height: 39px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 70px; height: 39px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 33px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 33px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 271px; height: 33px;">
# <p class="rvps52"><span class="rvts63"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%20274.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 31px; height: 33px;">
# <p class="rvps53"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 70px; height: 33px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20273.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 29px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 29px;">
# <p class="rvps42"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 271px; height: 29px;">
# <p class="rvps7"><span class="rvts55"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20272.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 31px; height: 29px;">
# <p class="rvps54"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 70px; height: 29px;">
# <p class="rvps5"><span class="rvts51"><br/></span></p>
# <p class="rvps55"><img alt="" src="lib/NewItem%20271.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 62px;">
# <p class="rvps6"><span class="rvts57">8.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 637px; height: 62px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps33"><img alt="" src="lib/NewItem%20270.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 32px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 155px; height: 32px;">
# <p class="rvps40"><span class="rvts50">40</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 147px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 287px; height: 32px;">
# <p class="rvps56"><span class="rvts50">55</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 27px;">
# <p class="rvps47"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 155px; height: 27px;">
# <p class="rvps48"><span class="rvts50">60</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 147px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 287px; height: 27px;">
# <p class="rvps57"><span class="rvts50">65</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 35px;">
# <p class="rvps6"><span class="rvts57">9.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 629px; height: 35px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps58"><img alt="" src="lib/NewItem%20269.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 32px;">
# <p class="rvps9"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 155px; height: 32px;">
# <p class="rvps40"><span class="rvts64">8</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 147px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 279px; height: 32px;">
# <p class="rvps56"><span class="rvts50">16</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 36px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 47px; height: 27px;">
# <p class="rvps47"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 155px; height: 27px;">
# <p class="rvps48"><span class="rvts50">32</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 147px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 279px; height: 27px;">
# <p class="rvps57"><span class="rvts50">64</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 65px;">
# <p class="rvps6"><span class="rvts68">10.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 590px; height: 65px;">
# <p class="rvps7"><span class="rvts69"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20268.jpg" style="width : 569px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 32px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 32px;">
# <p class="rvps40"><span class="rvts64">5</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 246px; height: 32px;">
# <p class="rvps56"><span class="rvts64">4</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 27px;">
# <p class="rvps60"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 27px;">
# <p class="rvps48"><span class="rvts64">2</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 246px; height: 27px;">
# <p class="rvps57"><span class="rvts64">1</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 48px;">
# <p class="rvps6"><span class="rvts68">11.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 270px; height: 48px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20267.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 73px; height: 48px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 48px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 49px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 49px;">
# <p class="rvps62"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 229px; height: 49px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20266.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 73px; height: 49px;">
# <p class="rvps63"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 49px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20265.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 45px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 45px;">
# <p class="rvps65"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 229px; height: 45px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20264.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 73px; height: 45px;">
# <p class="rvps67"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 45px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20263.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 68px;">
# <p class="rvps6"><span class="rvts68">12.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 610px; height: 68px;">
# <p class="rvps5"><span class="rvts63"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%20262.jpg" style="width : 591px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 32px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 32px;">
# <p class="rvps40"><span class="rvts64">4</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 32px;">
# <p class="rvps56"><span class="rvts64">5</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 27px;">
# <p class="rvps60"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 27px;">
# <p class="rvps48"><span class="rvts64">6</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 27px;">
# <p class="rvps57"><span class="rvts64">8</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 54px;">
# <p class="rvps6"><span class="rvts68">13.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 307px; height: 54px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20261.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 36px; height: 54px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 44px; height: 54px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 40px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 40px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 40px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20260.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 36px; height: 40px;">
# <p class="rvps70"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 44px; height: 40px;">
# <p class="rvps5"><span class="rvts59"><br/></span></p>
# <p class="rvps71"><img alt="" src="lib/NewItem%20259.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 53px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 53px;">
# <p class="rvps54"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 53px;">
# <p class="rvps7"><span class="rvts71"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20258.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 36px; height: 53px;">
# <p class="rvps72"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 44px; height: 53px;">
# <p class="rvps7"><span class="rvts55"><br/></span></p>
# <p class="rvps73"><img alt="" src="lib/NewItem%20257.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 62px;">
# <p class="rvps6"><span class="rvts68">14.</span></p>
# </td>, <td colspan="3" style="padding: 0px; vertical-align: top; width: 350px; height: 62px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20256.jpg" style="width : 328px; height : 50px; padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 62px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 31px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 31px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 167px; height: 31px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps74"><img alt="" src="lib/NewItem%20255.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 142px; height: 31px;">
# <p class="rvps75"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 31px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps76"><img alt="" src="lib/NewItem%20254.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 43px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 43px;">
# <p class="rvps54"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 167px; height: 43px;">
# <p class="rvps7"><span class="rvts71"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20253.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 142px; height: 43px;">
# <p class="rvps77"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 43px;">
# <p class="rvps7"><span class="rvts71"><br/></span></p>
# <p class="rvps78"><img alt="" src="lib/NewItem%20252.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 56px;">
# <p class="rvps6"><span class="rvts68">15.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 303px; height: 56px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20251.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 56px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 34px; height: 56px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 48px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 48px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 262px; height: 48px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20250.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 48px;">
# <p class="rvps79"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 34px; height: 48px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20249.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 47px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 47px;">
# <p class="rvps80"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 262px; height: 47px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20248.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 47px;">
# <p class="rvps81"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 34px; height: 47px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20247.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 45px;">
# <p class="rvps6"><span class="rvts68">16.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 528px; height: 45px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20246.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 48px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 48px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 48px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%20245.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 150px; height: 48px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 185px; height: 48px;">
# <p class="rvps2"><span class="rvts63"><br/></span></p>
# <p class="rvps55"><img alt="" src="lib/NewItem%20244.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 50px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 50px;">
# <p class="rvps80"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 151px; height: 50px;">
# <p class="rvps2"><span class="rvts52"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%20243.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 150px; height: 50px;">
# <p class="rvps24"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 185px; height: 50px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps55"><img alt="" src="lib/NewItem%20242.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 48px;">
# <p class="rvps6"><span class="rvts68">17.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 477px; height: 48px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20241.jpg" style="width : 450px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 35px; height: 57px;">
# <p class="rvps6"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 162px; height: 57px;">
# <p class="rvps7"><span class="rvts59"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%20240.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 141px; height: 57px;">
# <p class="rvps82"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 49px; height: 57px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20239.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 35px; height: 53px;">
# <p class="rvps83"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 162px; height: 53px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20238.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 141px; height: 53px;">
# <p class="rvps43"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 49px; height: 53px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20237.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 34px;">
# <p class="rvps6"><span class="rvts68">18.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 540px; height: 34px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20236.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 32px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 32px;">
# <p class="rvps40"><span class="rvts64">5</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 32px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 196px; height: 32px;">
# <p class="rvps56"><span class="rvts64">6</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 27px;">
# <p class="rvps60"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 149px; height: 27px;">
# <p class="rvps48"><span class="rvts64">7</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 153px; height: 27px;">
# <p class="rvps49"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 196px; height: 27px;">
# <p class="rvps57"><span class="rvts64">8</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 58px;">
# <p class="rvps6"><span class="rvts68">19.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 612px; height: 58px;">
# <p class="rvps7"><span class="rvts69"><br/></span></p>
# <p class="rvps36"><img alt="" src="lib/NewItem%20235.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 54px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 54px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 173px; height: 54px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20234.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 129px; height: 54px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 268px; height: 54px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20233.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 50px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 50px;">
# <p class="rvps54"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 173px; height: 50px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%20232.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 129px; height: 50px;">
# <p class="rvps43"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 268px; height: 50px;">
# <p class="rvps2"><span class="rvts63"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20231.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 60px;">
# <p class="rvps6"><span class="rvts68">20.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 610px; height: 60px;">
# <p class="rvps23"><img alt="" src="lib/NewItem%20230.jpg" style="width : 594px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 34px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 34px;">
# <p class="rvps53"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 171px; height: 34px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%20229.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 131px; height: 34px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 34px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20228.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 33px;">
# <p class="rvps2"><span class="rvts11"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 41px; height: 33px;">
# <p class="rvps86"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 171px; height: 33px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20227.jpg" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 131px; height: 33px;">
# <p class="rvps15"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 266px; height: 33px;">
# <p class="rvps7"><span class="rvts52"><br/></span></p>
# <p class="rvps21"><img alt="" src="lib/NewItem%20226.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 54px;">
# <p class="rvps6"><span class="rvts68">21.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 625px; height: 54px;">
# <p class="rvps7"><span class="rvts72"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20225.jpg" style="width : 597px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 79px;">
# <p class="rvps6"><span class="rvts68">22.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 565px; height: 79px;">
# <p class="rvps7"><span class="rvts72"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20224.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 74px;">
# <p class="rvps6"><span class="rvts68">23.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 615px; height: 74px;">
# <p class="rvps7"><span class="rvts69"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%20223.jpg" style="width : 592px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 55px;">
# <p class="rvps6"><span class="rvts68">24.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 615px; height: 55px;">
# <p class="rvps19"><img alt="" src="lib/NewItem%20222.jpg" style="width : 577px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 57px;">
# <p class="rvps6"><span class="rvts68">25.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 611px; height: 57px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem%20221.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 44px;">
# <p class="rvps6"><span class="rvts68">26.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 611px; height: 44px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%20220.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 96px;">
# <p class="rvps6"><span class="rvts68">27.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 638px; height: 96px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%20219.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 46px;">
# <p class="rvps6"><span class="rvts68">28.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 479px; height: 46px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20218.jpg" style="width : 451px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 35px;">
# <p class="rvps6"><span class="rvts68">29.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 443px; height: 35px;">
# <p class="rvps5"><span class="rvts63"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20217.jpg" style="width : 428px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 42px; height: 86px;">
# <p class="rvps6"><span class="rvts68">30.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 664px; height: 86px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%20216.png" style="width : 646px; height : 75px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 67px;">
# <p class="rvps6"><span class="rvts57">31.</span></p>
# </td>, <td colspan="4" style="padding: 0px; vertical-align: top; width: 616px; height: 67px;">
# <p class="rvps64"><img alt="" src="lib/NewItem%20215.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 31px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 31px;">
# <p class="rvps87"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 167px; height: 31px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps88"><img alt="" src="lib/NewItem%20214.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 139px; height: 31px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 271px; height: 31px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps89"><img alt="" src="lib/NewItem%20213.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps90"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 167px; height: 27px;">
# <p class="rvps5"><span class="rvts61"><br/></span></p>
# <p class="rvps91"><img alt="" src="lib/NewItem%20212.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 139px; height: 27px;">
# <p class="rvps92"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 271px; height: 27px;">
# <p class="rvps5"><span class="rvts61"><br/></span></p>
# <p class="rvps93"><img alt="" src="lib/NewItem%20211.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 226px;">
# <p class="rvps6"><span class="rvts68">32.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 632px; height: 226px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%20210.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 39px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 39px;">
# <p class="rvps87"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 592px; height: 39px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps73"><img alt="" src="lib/NewItem%20209.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 31px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 31px;">
# <p class="rvps94"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 592px; height: 31px;">
# <p class="rvps5"><span class="rvts60"><br/></span></p>
# <p class="rvps95"><img alt="" src="lib/NewItem%20208.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 29px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 40px; height: 29px;">
# <p class="rvps96"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 592px; height: 29px;">
# <p class="rvps2"><span class="rvts54"><br/></span></p>
# ...
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps179"><img alt="" src="lib/NewItem%2032.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 25px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 25px;">
# <p class="rvps180"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 282px; height: 25px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps131"><img alt="" src="lib/NewItem%2031.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 36px;">
# <p class="rvps6"><span class="rvts68">76.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 275px; height: 36px;">
# <p class="rvps2"><span class="rvts51"><br/></span></p>
# <p class="rvps174"><img alt="" src="lib/NewItem%2030.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 30px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 30px;">
# <p class="rvps141"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 233px; height: 30px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps136"><img alt="" src="lib/NewItem%2029.jpg" style="width : 104px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 29px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 29px;">
# <p class="rvps181"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 233px; height: 29px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps88"><img alt="" src="lib/NewItem%2028.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 35px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 35px;">
# <p class="rvps149"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 233px; height: 35px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps136"><img alt="" src="lib/NewItem%2027.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps164"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 233px; height: 27px;">
# <p class="rvps2"><span class="rvts63"><br/></span></p>
# <p class="rvps124"><img alt="" src="lib/NewItem%2026.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 94px;">
# <p class="rvps6"><span class="rvts68">77.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 275px; height: 94px;">
# <p class="rvps5"><span class="rvts71"><br/></span></p>
# <p class="rvps17"><img alt="" src="lib/NewItem%2025.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 56px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 56px;">
# <p class="rvps151"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 232px; height: 56px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%2024.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 63px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 63px;">
# <p class="rvps152"><span class="rvts49">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 232px; height: 63px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%2023.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 57px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 57px;">
# <p class="rvps152"><span class="rvts53">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 232px; height: 57px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%2022.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 59px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 59px;">
# <p class="rvps173"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 232px; height: 59px;">
# <p class="rvps7"><span class="rvts74"><br/></span></p>
# <p class="rvps66"><img alt="" src="lib/NewItem%2021.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 32px;">
# <p class="rvps6"><span class="rvts68">78.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 293px; height: 32px;">
# <p class="rvps7"><span class="rvts56"><br/></span></p>
# <p class="rvps182"><img alt="" src="lib/NewItem%2020.jpg" style="width : 251px; height : 50px; padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 35px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 30px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 30px;">
# <p class="rvps145"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 251px; height: 30px;">
# <p class="rvps7"><span class="rvts51"><br/></span></p>
# <p class="rvps179"><img alt="" src="lib/NewItem%2019.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 30px;">
# <p class="rvps11"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 35px; height: 30px;">
# <p class="rvps7"><span class="rvts63"><br/></span></p>
# <p class="rvps89"><img alt="" src="lib/NewItem%2018.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps183"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 251px; height: 27px;">
# <p class="rvps7"><span class="rvts52"><br/></span></p>
# <p class="rvps88"><img alt="" src="lib/NewItem%2017.png" style="padding : 1px;"/></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 54px; height: 27px;">
# <p class="rvps15"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 35px; height: 27px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps160"><img alt="" src="lib/NewItem%2016.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 30px;">
# <p class="rvps6"><span class="rvts68">79.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 582px; height: 30px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps174"><img alt="" src="lib/NewItem%2015.jpg" style="width : 388px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 35px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 35px;">
# <p class="rvps151"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 539px; height: 35px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps137"><img alt="" src="lib/NewItem%2014.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps172"><span class="rvts53">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 539px; height: 32px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps58"><img alt="" src="lib/NewItem%2013.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 35px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 35px;">
# <p class="rvps152"><span class="rvts50">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 539px; height: 35px;">
# <p class="rvps7"><span class="rvts61"><br/></span></p>
# <p class="rvps58"><img alt="" src="lib/NewItem%2012.jpg" style="width : 268px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps153"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 539px; height: 27px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps163"><img alt="" src="lib/NewItem%2011.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 90px;">
# <p class="rvps6"><span class="rvts57">80.</span></p>
# </td>, <td colspan="2" style="padding: 0px; vertical-align: top; width: 590px; height: 90px;">
# <p class="rvps7"><span class="rvts62"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%2010.jpg" style="width : 573px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps151"><span class="rvts49">A)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 547px; height: 32px;">
# <p class="rvps184"><span class="rvts64">4</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps152"><span class="rvts49">B)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 547px; height: 32px;">
# <p class="rvps184"><span class="rvts64">2</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 32px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 32px;">
# <p class="rvps152"><span class="rvts53">C)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 547px; height: 32px;">
# <p class="rvps184"><span class="rvts64">5</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 27px;">
# <p class="rvps2"><span class="rvts73"><br/></span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 42px; height: 27px;">
# <p class="rvps153"><span class="rvts53">D)</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 547px; height: 27px;">
# <p class="rvps185"><span class="rvts64">3</span></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 81px;">
# <p class="rvps6"><span class="rvts57">81.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 610px; height: 81px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps135"><img alt="" src="lib/NewItem%209.png" style="width : 597px; height : 50px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 84px;">
# <p class="rvps6"><span class="rvts57">82.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 631px; height: 84px;">
# <p class="rvps7"><span class="rvts55"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%208.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 78px;">
# <p class="rvps6"><span class="rvts57">83.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 366px; height: 78px;">
# <p class="rvps7"><span class="rvts60"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%207.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 96px;">
# <p class="rvps6"><span class="rvts57">84.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 665px; height: 96px;">
# <p class="rvps7"><span class="rvts55"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%206.jpg" style="width : 643px; height : 63px; padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 99px;">
# <p class="rvps6"><span class="rvts57">85.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 508px; height: 99px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps8"><img alt="" src="lib/NewItem%205.png" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 77px;">
# <p class="rvps6"><span class="rvts57">86.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 634px; height: 77px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps61"><img alt="" src="lib/NewItem%204.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 80px;">
# <p class="rvps6"><span class="rvts57">87.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 651px; height: 80px;">
# <p class="rvps7"><span class="rvts59"><br/></span></p>
# <p class="rvps34"><img alt="" src="lib/NewItem%203.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 154px;">
# <p class="rvps6"><span class="rvts57">88.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 655px; height: 154px;">
# <p class="rvps5"><span class="rvts59"><br/></span></p>
# <p class="rvps20"><img alt="" src="lib/NewItem%202.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 103px;">
# <p class="rvps6"><span class="rvts57">89.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 658px; height: 103px;">
# <p class="rvps7"><span class="rvts70"><br/></span></p>
# <p class="rvps64"><img alt="" src="lib/NewItem%201.jpg" style="padding : 1px;"/></p>
# </td>]
# [<td style="padding: 0px; vertical-align: top; width: 40px; height: 95px;">
# <p class="rvps6"><span class="rvts57">90.</span></p>
# </td>, <td style="padding: 0px; vertical-align: top; width: 665px; height: 95px;">
# <p class="rvps7"><span class="rvts54"><br/></span></p>
# <p class="rvps23"><img alt="" src="lib/NewItem.jpg" style="width : 642px; height : 50px; padding : 1px;"/></p>
# </td>]
