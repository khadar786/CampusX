# %%
import re
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urlparse

class QuestionExtraction:
    
    def __init__(self,url):
        self.url=url
        self.soup=None
        self.question_elements=None
        self.table_ele=[]
        self.tr_ele=[]
        self.td_ele=[]
        self.questions_list=[]
        self.dominURL=None
        self.libPath=None
    
    def urlParser(self):
        urlInfo = urlparse(self.url)
        self.domainURL=urlInfo.scheme+'://'+urlInfo.netloc
        self.libPath=self.domainURL+'/'+urlInfo.path.split('/')[1]+'/'
        
    def extractHtml(self):
        response = requests.get(self.url)
        
        try:
            # Check if the request was successful
            if response.status_code == 200:
                html_content = response.text

                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(html_content, 'html.parser')
                return soup
            else:
                return None
        except e:
            return None
    
    # Extract div with rvps elements
    def findQuestionElements(self):
        self.soup=self.extractHtml()
        specific_pattern = re.compile(r'rvps\d+')
        self.question_elements = self.soup.find_all('div', class_=specific_pattern) # Replace with your actual class name for questions
        return self.question_elements
    
    # Extract table elements
    def questionTableElements(self):
        self.urlParser()
        question_elements=self.findQuestionElements()
        
        for question_elem in question_elements:
            #specific_pattern = re.compile(r'rvps\d+')
            question_table = question_elem.find('table')
            self.table_ele.append(question_table)
        return self.table_ele
    
    # Extract tr elements
    def questionTrElements(self,question_table):
        question_trs=question_table.find_all('tr')
        return question_trs
    
    # Extract td elements
    def questionTrTdElements(self,question_tr):
        question_tds=question_tr.find_all('td')
        return question_tds
    
    # Extract all td elements
    def questionTableAllTdEelements(self,question_table):
        question_tds=question_table.find_all('td')
        return question_tds
    
    # Extract all p elements
    def questionTableAllPEelements(self,question_table):
        question_p_tags=question_table.find_all('p')
        return question_p_tags
    
    # Extract Question Text / Image
    def extractQuestionTextORImg(self,qtable_ptags,findIndex):
        qimg_text=''
        if len(qtable_ptags[(findIndex+1):])>0:
            
            for q_ptag in qtable_ptags[(findIndex+1):]:
                if q_ptag.find('img'):
                    qimg_text=self.libPath+''+q_ptag.find('img')['src']
                    break
                    
                if q_ptag.text.strip()!='':
                    qimg_text=q_ptag.text.strip()
                    break
        return qimg_text
    
    # Extract Question Text / Image
    def extractOptionTextORImg(self,qtable_ptags,findIndex):
        option_img_text=''
        if len(qtable_ptags[(findIndex+1):])>0:
            
            for q_ptag in qtable_ptags[(findIndex+1):]:
                if q_ptag.find('img'):
                    option_img_text=self.libPath+''+q_ptag.find('img')['src']
                    break
                
                if q_ptag.text.strip()!='':
                    option_img_text=q_ptag.text.strip()
                    break
                    
        return option_img_text
    
    #Questions
    def questionList(self):
        question_tables=self.questionTableElements()
        
        for question_table in question_tables:
            question_table_ptags=self.questionTableAllPEelements(question_table);
            
            qoptions=[]
            
            for qp_index in range(len(question_table_ptags)):
                q_ptag=question_table_ptags[qp_index]
                qpattern = re.compile(r'^\d+\.$')
                
                regex = r"^[A-D\)$]+"
                option_pattern = re.compile(regex)

                if qpattern.match(q_ptag.text.strip()):
                    qsno=q_ptag.text.strip()
                    qno=int(qsno.replace('.',''))
                    question=self.extractQuestionTextORImg(question_table_ptags,qp_index)
                    
                if qno>0:   
                    if option_pattern.match(q_ptag.text.strip()):
                        option_index=q_ptag.text.strip()
                        option=self.extractOptionTextORImg(question_table_ptags,qp_index)
                        qoptions.append({
                            'option_index':option_index.replace(')',''),
                            'option':option
                        })
                    
                
#                 self.questions_list.append({
#                     'qsno':qsno,
#                     'qno':qno,
#                     'question':question,
#                     'options':qoptions,
#                     'qtype':'M' if len(qoptions)>0 else 'N'
#                 })
                #print(question_table_ptags[qp_index])
                    
            #print("===========")
        return self.questions_list
        #print(self.questions_list)
            
#             question_trs=self.questionTrElements(question_table)
            
#             for question_tr in question_trs:
#                 question_tr_tds=self.questionTrTdElements(question_tr)
#                 #print(question_tr_tds)
#                 for question_td in question_tr_tds:
#                     question_p_tags=question_td.find_all('p');
#                     qpattern = re.compile(r'^\d+\.$')
                    
#                     if len(question_p_tags) == 1 and qpattern.match(question_p_tags[0].text.strip()):
#                             qsno=question_p_tags[0].text.strip()
#                             qno=qsno.replace('.','')
#                             question_img=question_tr.find('img')
#                             question=question_img['src']
#                             question_all_tds=self.questionTableAllTdEelements(question_table);
                            
                            
#                             for qtd in question_all_tds:
#                                 option_p_tags=qtd.find_all('p');
                                
#                                 regex = r"^[A-D\)$]+"
#                                 option_pattern = re.compile(regex)
#                                 #print(option_p_tags)
#                                 for option_tag in option_p_tags:
#                                     if option_pattern.match(option_tag.text):
#                                         #print(option_tag.text.strip())
#                                         option_index=option_tag.text.strip()
                                        
                                        
                                    
                                #option_pattern = re.compile(r'^\A-B+\)$')
                                #print(option_pattern.match(qtd))
                                #print(qtd)
                                #print(question_all_tds)
                            #options_pattern = re.compile(r'+[A-D]\) *')
                            #print(options_pattern.match(question_table))
                            #print(qsno,qno,question)
                            #print(qno,question_img)
                            #print(question_tr_tds[0])
                            #print(question_tr_tds[1])
            
        
    

# URL of the HTML content
url = 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/SR_SANKALP_QP_GT-513-01-2023ONLI.html'
quesObj=QuestionExtraction(url)
quesObj.questionList()
#print(quesObj.questionList())
# Out:
# [{'qsno': '1.',
#   'qno': 1,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20298.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '2.',
#   'qno': 2,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20293.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '3.',
#   'qno': 3,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20288.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '4.',
#   'qno': 4,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20283.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '5.',
#   'qno': 5,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20278.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '6.',
#   'qno': 6,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20276.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '7.',
#   'qno': 7,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20275.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '8.',
#   'qno': 8,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20270.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '9.',
#   'qno': 9,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20269.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '10.',
#   'qno': 10,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20268.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '11.',
#   'qno': 11,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20267.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '12.',
#   'qno': 12,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20262.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '13.',
#   'qno': 13,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20261.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '14.',
#   'qno': 14,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20256.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '15.',
#   'qno': 15,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20251.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '16.',
#   'qno': 16,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20246.png',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '17.',
#   'qno': 17,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20241.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '17.',
#   'qno': 17,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20241.jpg',
#   'options': [{'option_index': 'A',
#     'option': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20240.png'}],
#   'qtype': 'M'},
#  {'qsno': '18.',
#   'qno': 18,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20236.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '19.',
#   'qno': 19,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20235.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '20.',
#   'qno': 20,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20230.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '21.',
#   'qno': 21,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20225.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '22.',
#   'qno': 22,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20224.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '23.',
#   'qno': 23,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20223.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '24.',
#   'qno': 24,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20222.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '25.',
#   'qno': 25,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20221.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '26.',
#   'qno': 26,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20220.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '27.',
#   'qno': 27,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20219.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '28.',
#   'qno': 28,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20218.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '29.',
#   'qno': 29,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20217.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '30.',
#   'qno': 30,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20216.png',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '31.',
#   'qno': 31,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20215.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '32.',
#   'qno': 32,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20210.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '33.',
#   'qno': 33,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20205.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '34.',
#   'qno': 34,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20200.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '35.',
#   'qno': 35,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20195.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '35.',
#   'qno': 35,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20195.jpg',
#   'options': [{'option_index': 'C',
#     'option': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20192.png'}],
#   'qtype': 'M'},
#  {'qsno': '36.',
#   'qno': 36,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20190.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '37.',
#   'qno': 37,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20185.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '38.',
#   'qno': 38,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20180.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '39.',
#   'qno': 39,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20175.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '39.',
#   'qno': 39,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20175.jpg',
#   'options': [{'option_index': 'C',
#     'option': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20172.png'}],
#   'qtype': 'M'},
#  {'qsno': '40.',
#   'qno': 40,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20170.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '41.',
#   'qno': 41,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20165.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '42.',
#   'qno': 42,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20160.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '43.',
#   'qno': 43,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20155.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '44.',
#   'qno': 44,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20150.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '45.',
#   'qno': 45,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20145.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '46.',
#   'qno': 46,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20140.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '47.',
#   'qno': 47,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20135.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '48.',
#   'qno': 48,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20130.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '49.',
#   'qno': 49,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20125.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '50.',
#   'qno': 50,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20120.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '51.',
#   'qno': 51,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20115.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '52.',
#   'qno': 52,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20114.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '53.',
#   'qno': 53,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20113.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '54.',
#   'qno': 54,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20112.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '55.',
#   'qno': 55,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20111.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '56.',
#   'qno': 56,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20110.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '57.',
#   'qno': 57,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20109.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '58.',
#   'qno': 58,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20108.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '59.',
#   'qno': 59,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20107.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '60.',
#   'qno': 60,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20106.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '61.',
#   'qno': 61,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20105.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '62.',
#   'qno': 62,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20100.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '62.',
#   'qno': 62,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%20100.jpg',
#   'options': [{'option_index': 'C',
#     'option': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2097.jpg'}],
#   'qtype': 'M'},
#  {'qsno': '63.',
#   'qno': 63,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2095.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '64.',
#   'qno': 64,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2090.png',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '65.',
#   'qno': 65,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2085.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '66.',
#   'qno': 66,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2080.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '67.',
#   'qno': 67,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2075.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '68.',
#   'qno': 68,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2070.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '69.',
#   'qno': 69,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2065.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '70.',
#   'qno': 70,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2060.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '71.',
#   'qno': 71,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2055.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '72.',
#   'qno': 72,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2050.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '73.',
#   'qno': 73,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2045.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '74.',
#   'qno': 74,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2040.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '75.',
#   'qno': 75,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2035.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '76.',
#   'qno': 76,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2030.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '77.',
#   'qno': 77,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2025.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '78.',
#   'qno': 78,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2020.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '79.',
#   'qno': 79,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2015.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '80.',
#   'qno': 80,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%2010.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '81.',
#   'qno': 81,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%209.png',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '82.',
#   'qno': 82,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%208.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '83.',
#   'qno': 83,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%207.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '84.',
#   'qno': 84,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%206.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '85.',
#   'qno': 85,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%205.png',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '86.',
#   'qno': 86,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%204.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '87.',
#   'qno': 87,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%203.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '88.',
#   'qno': 88,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%202.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '89.',
#   'qno': 89,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem%201.jpg',
#   'options': [],
#   'qtype': 'N'},
#  {'qsno': '90.',
#   'qno': 90,
#   'question': 'https://vsa-digital.etutor.co/SR_SANKALP_QP_GT-513-01-2023ONLI/lib/NewItem.jpg',
#   'options': [],
#   'qtype': 'N'}]
